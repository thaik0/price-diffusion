# %% [markdown]
# # Stage 12B — Subsector and Peer Analysis
#
# **Research question:** Is the unconditional result hiding stronger relationships among economically connected firms?
#
# We describe convergence, peer catch-up, and initiator reversal by reviewed subsector, measure peer quality, and compare economic, trailing-correlation, and broad semiconductor peers.

# %% [markdown]
# ## Methodology and safeguards
#
# The peer-definition comparison holds baseline event dates fixed. Correlation peers are selected from returns strictly before each event and portfolios are frozen on the event date. Every result includes its sample size; groups below 30 are labeled descriptive-only and are not ranked.

# %%
from IPython.display import Image, display
from price_diffusion.research_diagnostics import load_diagnostic_inputs, run_peer_analysis

inputs = load_diagnostic_inputs()
artifacts = run_peer_analysis(inputs)

# %%
display(artifacts.tables['subsector_results'])
display(artifacts.tables['peer_quality'])
display(artifacts.tables['peer_definition_comparison'])
# Out:
#                   subsector  horizon             outcome  event_count  \
# 0       analog_mixed_signal        1         convergence          101
# 1       analog_mixed_signal        1        peer_catchup          101
# 2       analog_mixed_signal        1  initiator_reversal          101
# 3       analog_mixed_signal        3         convergence           83
# 4       analog_mixed_signal        3        peer_catchup           83
# 5       analog_mixed_signal        3  initiator_reversal           83
# 6       analog_mixed_signal        5         convergence           68
# 7       analog_mixed_signal        5        peer_catchup           68
# 8       analog_mixed_signal        5  initiator_reversal           68
# 9       analog_mixed_signal       10         convergence           39
# 10      analog_mixed_signal       10        peer_catchup           39
# 11      analog_mixed_signal       10  initiator_reversal           39
# ...

# %%
display(Image(filename=str(artifacts.paths['convergence_by_subsector'])))
display(Image(filename=str(artifacts.paths['peer_similarity_vs_convergence'])))

# %% [markdown]
# ## Interpretation
#
# Differences across definitions may reflect economic connectivity, measurement, or missing long-horizon peer observations. They are hypothesis-generating rather than a ranking exercise or a confirmatory test.
