# %% [markdown]
# # Stage 13 — Equipment Mechanism Analysis
#
# **Confirmatory hypothesis:** semiconductor-equipment events exhibit larger direction-normalized peer catch-up or a distinct initiator-reversal component because equipment firms share customer-capex and fabrication-cycle exposure. This hypothesis was motivated by Stage 12B and is not a search for the best subgroup.

# %% [markdown]
# ## Methodology
#
# The source module reports every equipment event by company and year, compares equipment with all non-equipment events, and fully discloses every other subsector. Raw peer and initiator CARs, direction-normalized peer catch-up and initiator reversal, and convergence are reported at 1, 5, and 10 days with confidence intervals, event counts, and small-sample labels.

# %%
from IPython.display import Image, display
from price_diffusion.mechanism_analysis import run_equipment_analysis

artifacts = run_equipment_analysis()

# %%
display(artifacts.tables['equipment_analysis'])
display(artifacts.tables['equipment_summary'])
display(artifacts.tables['equipment_vs_other_subsectors'])

# %%
display(Image(filename=str(artifacts.paths['equipment_vs_other'])))
display(Image(filename=str(artifacts.paths['equipment_event_path'])))
display(Image(filename=str(artifacts.paths['equipment_convergence_decomposition'])))

# %% [markdown]
# ## Economic interpretation and limitations
#
# Common customer concentration, shared wafer-fabrication capex budgets, and the semiconductor capital-equipment cycle are plausible interpretations, but the frozen data do not directly measure customer concentration or capex exposure. Company cells and long-horizon equipment samples are small, present-day classifications are retrospective, and the analysis is associational rather than causal.
